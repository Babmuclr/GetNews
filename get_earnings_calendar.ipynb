# %%
import urllib
from urllib import request  # urllib.requestモジュールをインポート
from bs4 import BeautifulSoup  # BeautifulSoupクラスをインポート

# %%
import datetime as dt 
now = dt.datetime.utcnow()
now -= dt.timedelta(days=1)
year, month, day = now.year, now.month, now.day
limit_date = str(year) + "-" + str(month) + "-" + str(day)
date = str(year) + "-" + str(month)
print(limit_date)
# Out:
# 2021-12-23

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
url = 'https://www.investing.com/earnings-calendar/' 
     
#　ヘッドレスモードでブラウザを起動
options = Options()
    
# ブラウザーを起動
driver = webdriver.Chrome('./chromedriver', options=options)
driver.get(url)
driver.implicitly_wait(10)

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, "html.parser")
soup = soup.find(id="earningsCalendarData")

# %%
data = soup.find_all("td")
x = []
for i in data:
    x.append(i.getText())
    print(i.getText())
# Out:
# Wednesday, December 15, 2021
#
#
#
#
# Lennar (LEN)
#
# 3.91
# /  4.15
# 8.43B
# /  8.51B
# 33.92B
#
#
# Thursday, December 16, 2021
#
#
#
#
# Adobe (ADBE)
#
# 3.2
# /  3.2
# 4.11B
# /  4.09B
# 271.03B
#
#
#
#
#
#
# Accenture (ACN)
#
# 2.78
# /  2.64
# 14.97B
# /  14.22B
# 254.89B
#
#
#
#
#
#
# FedEx (FDX)
#
# 4.83
# /  4.28
# 23.5B
# /  22.41B
# 67.25B
#
#
# Friday, December 17, 2021
#
#
#
#
# Darden Restaurants (DRI)
#
# 1.48
# /  1.43
# 2.27B
# /  2.23B
# 19.32B
#
#
# Monday, December 20, 2021
#
#
#
#
# Nike (NKE)
#
# 0.83
# /  0.6308
# 11.36B
# /  11.25B
# 262.23B
#
#
#
#
#
#
# Micron (MU)
#
# 2.16
# /  2.1
# 7.69B
# /  7.68B
# 105.77B
#
#
# Tuesday, December 21, 2021
#
#
#
#
# General Mills (GIS)
#
# 0.99
# /  1.05
# 5.02B
# /  4.83B
# 39.81B
#
#
# Wednesday, December 22, 2021
#
#
#
#
# Paychex (PAYX)
#
# 0.91
# /  0.7974
# 1.11B
# /  1.06B
# 48.43B
#
#
#
#
#
#
# Cintas (CTAS)
#
# 2.76
# /  2.64
# 1.92B
# /  1.9B
# 45.09B
#
#
#
#
#
#
# CarMax (KMX)
#
# 1.63
# /  1.47
# 8.53B
# /  7.28B
# 20.45B

# %%
def change_text(x):
    if x =="\n\n" or x == "" or x == "\xa0":
        return "NoData"
    elif "\xa0" in x:    
        x = x.replace("\xa0", "")
        if "\n" in x:
            x = x.replace("\n", "")
            if "                    " in x:
                x = x.replace("                    ", "")
        elif "/" in x:
            x = x.replace("/", "")
    return x

# %%
data = list(map(change_text,x))
li = [i for i in data if i != "NoData"]
li
# Out:
# ['Wednesday, December 15, 2021',
#  'Lennar(LEN)',
#  '3.91',
#  '4.15',
#  '8.43B',
#  '8.51B',
#  '33.92B',
#  'Thursday, December 16, 2021',
#  'Adobe(ADBE)',
#  '3.2',
#  '3.2',
#  '4.11B',
#  '4.09B',
#  '271.03B',
#  'Accenture(ACN)',
#  '2.78',
#  '2.64',
#  '14.97B',
#  '14.22B',
#  '254.89B',
#  'FedEx(FDX)',
#  '4.83',
#  '4.28',
#  '23.5B',
#  '22.41B',
#  '67.25B',
#  'Friday, December 17, 2021',
#  'Darden Restaurants(DRI)',
#  '1.48',
#  '1.43',
#  '2.27B',
#  '2.23B',
#  '19.32B',
#  'Monday, December 20, 2021',
#  'Nike(NKE)',
#  '0.83',
#  '0.6308',
#  '11.36B',
#  '11.25B',
#  '262.23B',
#  'Micron(MU)',
#  '2.16',
#  '2.1',
#  '7.69B',
#  '7.68B',
#  '105.77B',
#  'Tuesday, December 21, 2021',
#  'General Mills(GIS)',
#  '0.99',
#  '1.05',
#  '5.02B',
#  '4.83B',
#  '39.81B',
#  'Wednesday, December 22, 2021',
#  'Paychex(PAYX)',
#  '0.91',
#  '0.7974',
#  '1.11B',
#  '1.06B',
#  '48.43B',
#  'Cintas(CTAS)',
#  '2.76',
#  '2.64',
#  '1.92B',
#  '1.9B',
#  '45.09B',
#  'CarMax(KMX)',
#  '1.63',
#  '1.47',
#  '8.53B',
#  '7.28B',
#  '20.45B']

# %%
driver.quit()

# %%
li2 = []
day = ""
for i in li:
    if "December" in i:
        day = i
    else:
        li2.append([day, i])
li2
# Out:
# [['Wednesday, December 15, 2021', 'Lennar(LEN)'],
#  ['Wednesday, December 15, 2021', '3.91'],
#  ['Wednesday, December 15, 2021', '4.15'],
#  ['Wednesday, December 15, 2021', '8.43B'],
#  ['Wednesday, December 15, 2021', '8.51B'],
#  ['Wednesday, December 15, 2021', '33.92B'],
#  ['Thursday, December 16, 2021', 'Adobe(ADBE)'],
#  ['Thursday, December 16, 2021', '3.2'],
#  ['Thursday, December 16, 2021', '3.2'],
#  ['Thursday, December 16, 2021', '4.11B'],
#  ['Thursday, December 16, 2021', '4.09B'],
#  ['Thursday, December 16, 2021', '271.03B'],
#  ['Thursday, December 16, 2021', 'Accenture(ACN)'],
#  ['Thursday, December 16, 2021', '2.78'],
#  ['Thursday, December 16, 2021', '2.64'],
#  ['Thursday, December 16, 2021', '14.97B'],
#  ['Thursday, December 16, 2021', '14.22B'],
#  ['Thursday, December 16, 2021', '254.89B'],
#  ['Thursday, December 16, 2021', 'FedEx(FDX)'],
#  ['Thursday, December 16, 2021', '4.83'],
#  ['Thursday, December 16, 2021', '4.28'],
#  ['Thursday, December 16, 2021', '23.5B'],
#  ['Thursday, December 16, 2021', '22.41B'],
#  ['Thursday, December 16, 2021', '67.25B'],
#  ['Friday, December 17, 2021', 'Darden Restaurants(DRI)'],
#  ['Friday, December 17, 2021', '1.48'],
#  ['Friday, December 17, 2021', '1.43'],
#  ['Friday, December 17, 2021', '2.27B'],
#  ['Friday, December 17, 2021', '2.23B'],
#  ['Friday, December 17, 2021', '19.32B'],
#  ['Monday, December 20, 2021', 'Nike(NKE)'],
#  ['Monday, December 20, 2021', '0.83'],
#  ['Monday, December 20, 2021', '0.6308'],
#  ['Monday, December 20, 2021', '11.36B'],
#  ['Monday, December 20, 2021', '11.25B'],
#  ['Monday, December 20, 2021', '262.23B'],
#  ['Monday, December 20, 2021', 'Micron(MU)'],
#  ['Monday, December 20, 2021', '2.16'],
#  ['Monday, December 20, 2021', '2.1'],
#  ['Monday, December 20, 2021', '7.69B'],
#  ['Monday, December 20, 2021', '7.68B'],
#  ['Monday, December 20, 2021', '105.77B'],
#  ['Tuesday, December 21, 2021', 'General Mills(GIS)'],
#  ['Tuesday, December 21, 2021', '0.99'],
#  ['Tuesday, December 21, 2021', '1.05'],
#  ['Tuesday, December 21, 2021', '5.02B'],
#  ['Tuesday, December 21, 2021', '4.83B'],
#  ['Tuesday, December 21, 2021', '39.81B'],
#  ['Wednesday, December 22, 2021', 'Paychex(PAYX)'],
#  ['Wednesday, December 22, 2021', '0.91'],
#  ['Wednesday, December 22, 2021', '0.7974'],
#  ['Wednesday, December 22, 2021', '1.11B'],
#  ['Wednesday, December 22, 2021', '1.06B'],
#  ['Wednesday, December 22, 2021', '48.43B'],
#  ['Wednesday, December 22, 2021', 'Cintas(CTAS)'],
#  ['Wednesday, December 22, 2021', '2.76'],
#  ['Wednesday, December 22, 2021', '2.64'],
#  ['Wednesday, December 22, 2021', '1.92B'],
#  ['Wednesday, December 22, 2021', '1.9B'],
#  ['Wednesday, December 22, 2021', '45.09B'],
#  ['Wednesday, December 22, 2021', 'CarMax(KMX)'],
#  ['Wednesday, December 22, 2021', '1.63'],
#  ['Wednesday, December 22, 2021', '1.47'],
#  ['Wednesday, December 22, 2021', '8.53B'],
#  ['Wednesday, December 22, 2021', '7.28B'],
#  ['Wednesday, December 22, 2021', '20.45B']]

# %%
name_li = ["Company","EPS(Reported)","EPS(Estimated)","Revenue(Reported)","Revenue(Estimated)","MarketCap"]
ans = []
for num in range(len(li2) // 6):
    dic = {}
    dic["Time"] = li2[6 * num][0]
    for i in range(6):
        dic[name_li[i]] = li2[6 * num + i][1]
    ans.append(dic)
ans
# Out:
# [{'Time': 'Wednesday, December 15, 2021',
#   'Company': 'Lennar(LEN)',
#   'EPS(Reported)': '3.91',
#   'EPS(Estimated)': '4.15',
#   'Revenue(Reported)': '8.43B',
#   'Revenue(Estimated)': '8.51B',
#   'MarketCap': '33.92B'},
#  {'Time': 'Thursday, December 16, 2021',
#   'Company': 'Adobe(ADBE)',
#   'EPS(Reported)': '3.2',
#   'EPS(Estimated)': '3.2',
#   'Revenue(Reported)': '4.11B',
#   'Revenue(Estimated)': '4.09B',
#   'MarketCap': '271.03B'},
#  {'Time': 'Thursday, December 16, 2021',
#   'Company': 'Accenture(ACN)',
#   'EPS(Reported)': '2.78',
#   'EPS(Estimated)': '2.64',
#   'Revenue(Reported)': '14.97B',
#   'Revenue(Estimated)': '14.22B',
#   'MarketCap': '254.89B'},
#  {'Time': 'Thursday, December 16, 2021',
#   'Company': 'FedEx(FDX)',
#   'EPS(Reported)': '4.83',
#   'EPS(Estimated)': '4.28',
#   'Revenue(Reported)': '23.5B',
#   'Revenue(Estimated)': '22.41B',
#   'MarketCap': '67.25B'},
#  {'Time': 'Friday, December 17, 2021',
#   'Company': 'Darden Restaurants(DRI)',
#   'EPS(Reported)': '1.48',
#   'EPS(Estimated)': '1.43',
#   'Revenue(Reported)': '2.27B',
#   'Revenue(Estimated)': '2.23B',
#   'MarketCap': '19.32B'},
#  {'Time': 'Monday, December 20, 2021',
#   'Company': 'Nike(NKE)',
#   'EPS(Reported)': '0.83',
#   'EPS(Estimated)': '0.6308',
#   'Revenue(Reported)': '11.36B',
#   'Revenue(Estimated)': '11.25B',
#   'MarketCap': '262.23B'},
#  {'Time': 'Monday, December 20, 2021',
#   'Company': 'Micron(MU)',
#   'EPS(Reported)': '2.16',
#   'EPS(Estimated)': '2.1',
#   'Revenue(Reported)': '7.69B',
#   'Revenue(Estimated)': '7.68B',
#   'MarketCap': '105.77B'},
#  {'Time': 'Tuesday, December 21, 2021',
#   'Company': 'General Mills(GIS)',
#   'EPS(Reported)': '0.99',
#   'EPS(Estimated)': '1.05',
#   'Revenue(Reported)': '5.02B',
#   'Revenue(Estimated)': '4.83B',
#   'MarketCap': '39.81B'},
#  {'Time': 'Wednesday, December 22, 2021',
#   'Company': 'Paychex(PAYX)',
#   'EPS(Reported)': '0.91',
#   'EPS(Estimated)': '0.7974',
#   'Revenue(Reported)': '1.11B',
#   'Revenue(Estimated)': '1.06B',
#   'MarketCap': '48.43B'},
#  {'Time': 'Wednesday, December 22, 2021',
#   'Company': 'Cintas(CTAS)',
#   'EPS(Reported)': '2.76',
#   'EPS(Estimated)': '2.64',
#   'Revenue(Reported)': '1.92B',
#   'Revenue(Estimated)': '1.9B',
#   'MarketCap': '45.09B'},
#  {'Time': 'Wednesday, December 22, 2021',
#   'Company': 'CarMax(KMX)',
#   'EPS(Reported)': '1.63',
#   'EPS(Estimated)': '1.47',
#   'Revenue(Reported)': '8.53B',
#   'Revenue(Estimated)': '7.28B',
#   'MarketCap': '20.45B'}]

# %%
with open("./stocks.txt", mode="w") as f:
    for i in ans:
        f.write(i["Company"]+ "\n")
